# %%
import pandas as pd

# %%
df_meta = pd.read_csv('../../accession_lists/Public_AML_RNA_SraRunTable.txt', sep='\t')

# %%
df_data = pd.read_csv('../data_files/aml.3snps.norm.csv', index_col=0)

# %%
df_data.head()
# Out:
#                                                                               file_location  \
# aml_aabspliced_SRR948685.sam.sorted.bam   ../aml_results/aml_aabspliced_SRR948685.sam.so...
# aml_aabspliced_SRR948686.sam.sorted.bam   ../aml_results/aml_aabspliced_SRR948686.sam.so...
# aml_aabspliced_SRR1918637.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918637.sam.s...
# aml_aabspliced_SRR1918638.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918638.sam.s...
# aml_aabspliced_SRR1918639.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918639.sam.s...
#
#                                          source  alignment_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam     AML              197
# aml_aabspliced_SRR948686.sam.sorted.bam     AML              161
# aml_aabspliced_SRR1918637.sam.sorted.bam    AML             3736
# aml_aabspliced_SRR1918638.sam.sorted.bam    AML             3550
# aml_aabspliced_SRR1918639.sam.sorted.bam    AML              182
#
# ...

# %%
df_data.set_index('srr_acc',inplace=True)

# %%
df_data.head()
# Out:
#                                                 file_location source  \
# srr_acc
# SRR948685   ../aml_results/aml_aabspliced_SRR948685.sam.so...    AML
# SRR948686   ../aml_results/aml_aabspliced_SRR948686.sam.so...    AML
# SRR1918637  ../aml_results/aml_aabspliced_SRR1918637.sam.s...    AML
# SRR1918638  ../aml_results/aml_aabspliced_SRR1918638.sam.s...    AML
# SRR1918639  ../aml_results/aml_aabspliced_SRR1918639.sam.s...    AML
#
#             alignment_count  alpha_wt_count  alpha_dup_count  beta_count  \
# srr_acc
# SRR948685               197               8                9         180
# SRR948686               161               4                4         153
# SRR1918637             3736            1776             1581         379
# SRR1918638             3550            1669             1482         399
# SRR1918639              182              78               70          34
#
#             alpha_wt_zero_edit_count  alpha_dup_zero_edit_count  \
# srr_acc
# ...

# %%
df_meta.set_index('Run', inplace=True)

# %%
df_meta.head()
# Out:
#           Assay_Type AssemblyName  AvgSpotLen   BioProject     BioSample  \
# Run
# SRR330925    RNA-Seq          NaN          36  PRJNA145991  SAMN00709303
# SRR330926    RNA-Seq          NaN          36  PRJNA145991  SAMN00709304
# SRR330927    RNA-Seq          NaN          36  PRJNA145991  SAMN00709305
# SRR330928    RNA-Seq          NaN          36  PRJNA145991  SAMN00709306
# SRR330929    RNA-Seq          NaN          36  PRJNA145991  SAMN00709307
#
#           Center_Name DATASTORE_filetype Experiment  InsertSize  \
# Run
# SRR330925         GEO                sra  SRX091763           0
# SRR330926         GEO                sra  SRX091764           0
# SRR330927         GEO                sra  SRX091765           0
# SRR330928         GEO                sra  SRX091766           0
# SRR330929         GEO                sra  SRX091767           0
#
#                             Instrument      ...      SRA_Sample  SRA_Study  \
# Run                                         ...
# ...

# %%
del df_meta.index.name
del df_data.index.name

# %%
df_meta.head()
# Out:
#           Assay_Type AssemblyName  AvgSpotLen   BioProject     BioSample  \
# SRR330925    RNA-Seq          NaN          36  PRJNA145991  SAMN00709303
# SRR330926    RNA-Seq          NaN          36  PRJNA145991  SAMN00709304
# SRR330927    RNA-Seq          NaN          36  PRJNA145991  SAMN00709305
# SRR330928    RNA-Seq          NaN          36  PRJNA145991  SAMN00709306
# SRR330929    RNA-Seq          NaN          36  PRJNA145991  SAMN00709307
#
#           Center_Name DATASTORE_filetype Experiment  InsertSize  \
# SRR330925         GEO                sra  SRX091763           0
# SRR330926         GEO                sra  SRX091764           0
# SRR330927         GEO                sra  SRX091765           0
# SRR330928         GEO                sra  SRX091766           0
# SRR330929         GEO                sra  SRX091767           0
#
#                             Instrument      ...      SRA_Sample  SRA_Study  \
# ...

# %%
master_df = df_meta.join(df_data)

# %%
master_df.to_csv('aml.normal.meta.csv')
