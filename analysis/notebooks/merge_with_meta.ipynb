# %% [markdown]
# ## Merge with Metadata
#
# This notebook takes a CSV produced by run_pipeline.py and merges it with the SRA Run Table TSV file. It optionally  normalises by Mbases as well if this is required. Note this will override normalisation by number of reads if this has already been done.

# %%
import pandas as pd
import re

# %%
df_meta = pd.read_csv('../../accession_lists/allergy_SRARunTable.txt', sep='\t')
df_data = pd.read_csv('../data_files/allergy.allergy.csv', index_col=0)
output_name = 'allergy.meta.mbase_norm.csv'
normalise_with_mbases = True

# %%
df_data.head()
# Out:
#                                                                        file_location  \
# allergy.SRR2240319.sam.sorted.bam  ../results/allergy_results/allergy.SRR2240319....
# allergy.SRR2240320.sam.sorted.bam  ../results/allergy_results/allergy.SRR2240320....
# allergy.SRR2240321.sam.sorted.bam  ../results/allergy_results/allergy.SRR2240321....
# allergy.SRR2240322.sam.sorted.bam  ../results/allergy_results/allergy.SRR2240322....
# allergy.SRR2240323.sam.sorted.bam  ../results/allergy_results/allergy.SRR2240323....
#
#                                     source  alignment_count  alpha_wt_count  \
# allergy.SRR2240319.sam.sorted.bam  allergy                0               0
# allergy.SRR2240320.sam.sorted.bam  allergy                0               0
# allergy.SRR2240321.sam.sorted.bam  allergy                0               0
# allergy.SRR2240322.sam.sorted.bam  allergy                0               0
# allergy.SRR2240323.sam.sorted.bam  allergy                0               0
#
#                                    alpha_dup_count  beta_count  \
# allergy.SRR2240319.sam.sorted.bam                0           0
# allergy.SRR2240320.sam.sorted.bam                0           0
# allergy.SRR2240321.sam.sorted.bam                0           0
# allergy.SRR2240322.sam.sorted.bam                0           0
# allergy.SRR2240323.sam.sorted.bam                0           0
#
#                                    alpha_wt_zero_edit_count  \
# allergy.SRR2240319.sam.sorted.bam                         0
# allergy.SRR2240320.sam.sorted.bam                         0
# allergy.SRR2240321.sam.sorted.bam                         0
# allergy.SRR2240322.sam.sorted.bam                         0
# allergy.SRR2240323.sam.sorted.bam                         0
#
#                                    alpha_dup_zero_edit_count  \
# allergy.SRR2240319.sam.sorted.bam                          0
# allergy.SRR2240320.sam.sorted.bam                          0
# allergy.SRR2240321.sam.sorted.bam                          0
# allergy.SRR2240322.sam.sorted.bam                          0
# allergy.SRR2240323.sam.sorted.bam                          0
#
#                                    beta_zero_edit_count  \
# allergy.SRR2240319.sam.sorted.bam                     0
# allergy.SRR2240320.sam.sorted.bam                     0
# allergy.SRR2240321.sam.sorted.bam                     0
# allergy.SRR2240322.sam.sorted.bam                     0
# allergy.SRR2240323.sam.sorted.bam                     0
#
#                                    alpha_read_covers_snps_count  \
# allergy.SRR2240319.sam.sorted.bam                             0
# allergy.SRR2240320.sam.sorted.bam                             0
# allergy.SRR2240321.sam.sorted.bam                             0
# allergy.SRR2240322.sam.sorted.bam                             0
# allergy.SRR2240323.sam.sorted.bam                             0
#
#                                    alpha_dup_read_covers_snps_count  \
# allergy.SRR2240319.sam.sorted.bam                                 0
# allergy.SRR2240320.sam.sorted.bam                                 0
# allergy.SRR2240321.sam.sorted.bam                                 0
# allergy.SRR2240322.sam.sorted.bam                                 0
# allergy.SRR2240323.sam.sorted.bam                                 0
#
#                                    beta_read_covers_snps_count  \
# allergy.SRR2240319.sam.sorted.bam                            0
# allergy.SRR2240320.sam.sorted.bam                            0
# allergy.SRR2240321.sam.sorted.bam                            0
# allergy.SRR2240322.sam.sorted.bam                            0
# allergy.SRR2240323.sam.sorted.bam                            0
#
#                                    alpha_read_covers_snps_count_exact  \
# allergy.SRR2240319.sam.sorted.bam                                   0
# allergy.SRR2240320.sam.sorted.bam                                   0
# allergy.SRR2240321.sam.sorted.bam                                   0
# allergy.SRR2240322.sam.sorted.bam                                   0
# allergy.SRR2240323.sam.sorted.bam                                   0
#
#                                    alpha_dup_read_covers_snps_count_exact  \
# allergy.SRR2240319.sam.sorted.bam                                       0
# allergy.SRR2240320.sam.sorted.bam                                       0
# allergy.SRR2240321.sam.sorted.bam                                       0
# allergy.SRR2240322.sam.sorted.bam                                       0
# allergy.SRR2240323.sam.sorted.bam                                       0
#
#                                    beta_read_covers_snps_count_exact
# allergy.SRR2240319.sam.sorted.bam                                  0
# allergy.SRR2240320.sam.sorted.bam                                  0
# allergy.SRR2240321.sam.sorted.bam                                  0
# allergy.SRR2240322.sam.sorted.bam                                  0
# allergy.SRR2240323.sam.sorted.bam                                  0

# %%
def get_srr_accession(df):
    
    pattern = re.compile(r"[DSE]RR[0-9]+")
    
    file = df['file_location']
    
    return re.search(pattern, file).group(0)

# %%
df_data['srr_acc'] = df_data.apply(get_srr_accession, axis=1)

# %%
df_data.set_index('srr_acc',inplace=True)

# %%
df_data.head()
# Out:
#                                                 file_location   source  \
# srr_acc
# SRR2240319  ../results/allergy_results/allergy.SRR2240319....  allergy
# SRR2240320  ../results/allergy_results/allergy.SRR2240320....  allergy
# SRR2240321  ../results/allergy_results/allergy.SRR2240321....  allergy
# SRR2240322  ../results/allergy_results/allergy.SRR2240322....  allergy
# SRR2240323  ../results/allergy_results/allergy.SRR2240323....  allergy
#
#             alignment_count  alpha_wt_count  alpha_dup_count  beta_count  \
# srr_acc
# SRR2240319                0               0                0           0
# SRR2240320                0               0                0           0
# SRR2240321                0               0                0           0
# SRR2240322                0               0                0           0
# SRR2240323                0               0                0           0
#
#             alpha_wt_zero_edit_count  alpha_dup_zero_edit_count  \
# srr_acc
# SRR2240319                         0                          0
# SRR2240320                         0                          0
# SRR2240321                         0                          0
# SRR2240322                         0                          0
# SRR2240323                         0                          0
#
#             beta_zero_edit_count  alpha_read_covers_snps_count  \
# srr_acc
# SRR2240319                     0                             0
# SRR2240320                     0                             0
# SRR2240321                     0                             0
# SRR2240322                     0                             0
# SRR2240323                     0                             0
#
#             alpha_dup_read_covers_snps_count  beta_read_covers_snps_count  \
# srr_acc
# SRR2240319                                 0                            0
# SRR2240320                                 0                            0
# SRR2240321                                 0                            0
# SRR2240322                                 0                            0
# SRR2240323                                 0                            0
#
#             alpha_read_covers_snps_count_exact  \
# srr_acc
# SRR2240319                                   0
# SRR2240320                                   0
# SRR2240321                                   0
# SRR2240322                                   0
# SRR2240323                                   0
#
#             alpha_dup_read_covers_snps_count_exact  \
# srr_acc
# SRR2240319                                       0
# SRR2240320                                       0
# SRR2240321                                       0
# SRR2240322                                       0
# SRR2240323                                       0
#
#             beta_read_covers_snps_count_exact
# srr_acc
# SRR2240319                                  0
# SRR2240320                                  0
# SRR2240321                                  0
# SRR2240322                                  0
# SRR2240323                                  0

# %%
df_meta.set_index('Run', inplace=True)

# %%
df_meta.head()
# Out:
#            Assay_Type  AvgSpotLen   BioProject     BioSample Center_Name  \
# Run
# SRR2240322    RNA-Seq          51  PRJNA287538  SAMN04028900         GEO
# SRR2240323    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240324    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240325    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240326    RNA-Seq          51  PRJNA287538  SAMN04028902         GEO
#
#             Experiment           Instrument LibrarySelection Library_Name  \
# Run
# SRR2240322  SRX1182514  Illumina HiSeq 2500             cDNA          NaN
# SRR2240323  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240324  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240325  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240326  SRX1182516  Illumina HiSeq 2500             cDNA          NaN
#
#               LoadDate ...   DATASTORE_filetype  DATASTORE_provider  \
# Run                    ...
# SRR2240322  2015-09-04 ...                  sra                ncbi
# SRR2240323  2015-09-04 ...                  sra                ncbi
# SRR2240324  2015-09-04 ...                  sra                ncbi
# SRR2240325  2015-09-04 ...                  sra                ncbi
# SRR2240326  2015-09-04 ...                  sra                ncbi
#
#            InsertSize LibraryLayout   LibrarySource      Organism analyte  \
# Run
# SRR2240322          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240323          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240324          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240325          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240326          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
#
#            biomaterial_provider health_state  sex
# Run
# SRR2240322                  NaN          NaN  NaN
# SRR2240323                  NaN          NaN  NaN
# SRR2240324                  NaN          NaN  NaN
# SRR2240325                  NaN          NaN  NaN
# SRR2240326                  NaN          NaN  NaN
#
# [5 rows x 39 columns]

# %%
del df_meta.index.name
del df_data.index.name

# %%
df_meta.head()
# Out:
#            Assay_Type  AvgSpotLen   BioProject     BioSample Center_Name  \
# SRR2240322    RNA-Seq          51  PRJNA287538  SAMN04028900         GEO
# SRR2240323    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240324    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240325    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240326    RNA-Seq          51  PRJNA287538  SAMN04028902         GEO
#
#             Experiment           Instrument LibrarySelection Library_Name  \
# SRR2240322  SRX1182514  Illumina HiSeq 2500             cDNA          NaN
# SRR2240323  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240324  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240325  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240326  SRX1182516  Illumina HiSeq 2500             cDNA          NaN
#
#               LoadDate ...   DATASTORE_filetype  DATASTORE_provider  \
# SRR2240322  2015-09-04 ...                  sra                ncbi
# SRR2240323  2015-09-04 ...                  sra                ncbi
# SRR2240324  2015-09-04 ...                  sra                ncbi
# SRR2240325  2015-09-04 ...                  sra                ncbi
# SRR2240326  2015-09-04 ...                  sra                ncbi
#
#            InsertSize LibraryLayout   LibrarySource      Organism analyte  \
# SRR2240322          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240323          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240324          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240325          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
# SRR2240326          0        SINGLE  TRANSCRIPTOMIC  Homo sapiens     NaN
#
#            biomaterial_provider health_state  sex
# SRR2240322                  NaN          NaN  NaN
# SRR2240323                  NaN          NaN  NaN
# SRR2240324                  NaN          NaN  NaN
# SRR2240325                  NaN          NaN  NaN
# SRR2240326                  NaN          NaN  NaN
#
# [5 rows x 39 columns]

# %%
master_df = df_meta.join(df_data)

# %%
master_df.columns
# Out:
# Index(['Assay_Type', 'AvgSpotLen', 'BioProject', 'BioSample', 'Center_Name',
#        'Experiment', 'Instrument', 'LibrarySelection', 'Library_Name',
#        'LoadDate', 'MBases', 'MBytes', 'Platform', 'ReleaseDate', 'SRA_Sample',
#        'SRA_Study', 'Sample_Name', 'age', 'cell_type', 'isolate',
#        'patient_phenotype', 'run_label', 'seasonality', 'source_name',
#        'timepoint', 'tissue', 'treatment', 'BioSampleModel', 'Consent',
#        'DATASTORE_filetype', 'DATASTORE_provider', 'InsertSize',
#        'LibraryLayout', 'LibrarySource', 'Organism', 'analyte',
#        'biomaterial_provider', 'health_state', 'sex', 'file_location',
#        'source', 'alignment_count', 'alpha_wt_count', 'alpha_dup_count',
#        'beta_count', 'alpha_wt_zero_edit_count', 'alpha_dup_zero_edit_count',
#        'beta_zero_edit_count', 'alpha_read_covers_snps_count',
#        'alpha_dup_read_covers_snps_count', 'beta_read_covers_snps_count',
#        'alpha_read_covers_snps_count_exact',
#        'alpha_dup_read_covers_snps_count_exact',
#        'beta_read_covers_snps_count_exact'],
#       dtype='object')

# %%
if normalise_with_mbases == True:


    master_df['norm_alignment_count'] = master_df['alignment_count'] / (master_df['MBases'])
    master_df['norm_alpha_wt_count'] = master_df['alpha_wt_count'] / (master_df['MBases'])
    master_df['norm_alpha_dup_count'] = master_df['alpha_dup_count'] / (master_df['MBases'])
    master_df['norm_beta_count'] = master_df['beta_count'] / (master_df['MBases'])
    master_df['norm_alpha_read_covers_snps_count_exact'] = master_df['alpha_read_covers_snps_count_exact'] / (master_df['MBases'])
    master_df['norm_alpha_dup_read_covers_snps_count_exact'] = master_df['alpha_dup_read_covers_snps_count_exact'] / (master_df['MBases'])
    master_df['norm_beta_read_covers_snps_count_exact'] = master_df['beta_read_covers_snps_count_exact'] / (master_df['MBases'])

# %%
master_df.head()
# Out:
#            Assay_Type  AvgSpotLen   BioProject     BioSample Center_Name  \
# SRR2240322    RNA-Seq          51  PRJNA287538  SAMN04028900         GEO
# SRR2240323    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240324    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240325    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240326    RNA-Seq          51  PRJNA287538  SAMN04028902         GEO
#
#             Experiment           Instrument LibrarySelection Library_Name  \
# SRR2240322  SRX1182514  Illumina HiSeq 2500             cDNA          NaN
# SRR2240323  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240324  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240325  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240326  SRX1182516  Illumina HiSeq 2500             cDNA          NaN
#
#               LoadDate                  ...                    \
# SRR2240322  2015-09-04                  ...
# SRR2240323  2015-09-04                  ...
# SRR2240324  2015-09-04                  ...
# SRR2240325  2015-09-04                  ...
# SRR2240326  2015-09-04                  ...
#
#             alpha_read_covers_snps_count_exact  \
# SRR2240322                                   0
# SRR2240323                                   0
# SRR2240324                                   0
# SRR2240325                                   0
# SRR2240326                                   0
#
#             alpha_dup_read_covers_snps_count_exact  \
# SRR2240322                                       0
# SRR2240323                                       0
# SRR2240324                                       0
# SRR2240325                                       0
# SRR2240326                                       0
#
#            beta_read_covers_snps_count_exact norm_alignment_count  \
# SRR2240322                                 0             0.000000
# SRR2240323                                 0             0.000000
# SRR2240324                                 0                  NaN
# SRR2240325                                 0             0.000000
# SRR2240326                                 0             0.006289
#
#            norm_alpha_wt_count norm_alpha_dup_count norm_beta_count  \
# SRR2240322                 0.0                  0.0        0.000000
# SRR2240323                 0.0                  0.0        0.000000
# SRR2240324                 NaN                  NaN             NaN
# SRR2240325                 0.0                  0.0        0.000000
# SRR2240326                 0.0                  0.0        0.006289
#
#            norm_alpha_read_covers_snps_count_exact  \
# SRR2240322                                     0.0
# SRR2240323                                     0.0
# SRR2240324                                     NaN
# SRR2240325                                     0.0
# SRR2240326                                     0.0
#
#            norm_alpha_dup_read_covers_snps_count_exact  \
# SRR2240322                                         0.0
# SRR2240323                                         0.0
# SRR2240324                                         NaN
# SRR2240325                                         0.0
# SRR2240326                                         0.0
#
#            norm_beta_read_covers_snps_count_exact
# SRR2240322                                    0.0
# SRR2240323                                    0.0
# SRR2240324                                    NaN
# SRR2240325                                    0.0
# SRR2240326                                    0.0
#
# [5 rows x 61 columns]

# %%
master_df.to_csv(output_name)

# %%
master_df.head()
# Out:
#            Assay_Type  AvgSpotLen   BioProject     BioSample Center_Name  \
# SRR2240322    RNA-Seq          51  PRJNA287538  SAMN04028900         GEO
# SRR2240323    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240324    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240325    RNA-Seq          51  PRJNA287538  SAMN04028901         GEO
# SRR2240326    RNA-Seq          51  PRJNA287538  SAMN04028902         GEO
#
#             Experiment           Instrument LibrarySelection Library_Name  \
# SRR2240322  SRX1182514  Illumina HiSeq 2500             cDNA          NaN
# SRR2240323  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240324  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240325  SRX1182515  Illumina HiSeq 2500             cDNA          NaN
# SRR2240326  SRX1182516  Illumina HiSeq 2500             cDNA          NaN
#
#               LoadDate                  ...                    \
# SRR2240322  2015-09-04                  ...
# SRR2240323  2015-09-04                  ...
# SRR2240324  2015-09-04                  ...
# SRR2240325  2015-09-04                  ...
# SRR2240326  2015-09-04                  ...
#
#             alpha_read_covers_snps_count_exact  \
# SRR2240322                                   0
# SRR2240323                                   0
# SRR2240324                                   0
# SRR2240325                                   0
# SRR2240326                                   0
#
#             alpha_dup_read_covers_snps_count_exact  \
# SRR2240322                                       0
# SRR2240323                                       0
# SRR2240324                                       0
# SRR2240325                                       0
# SRR2240326                                       0
#
#            beta_read_covers_snps_count_exact norm_alignment_count  \
# SRR2240322                                 0             0.000000
# SRR2240323                                 0             0.000000
# SRR2240324                                 0                  NaN
# SRR2240325                                 0             0.000000
# SRR2240326                                 0             0.006289
#
#            norm_alpha_wt_count norm_alpha_dup_count norm_beta_count  \
# SRR2240322                 0.0                  0.0        0.000000
# SRR2240323                 0.0                  0.0        0.000000
# SRR2240324                 NaN                  NaN             NaN
# SRR2240325                 0.0                  0.0        0.000000
# SRR2240326                 0.0                  0.0        0.006289
#
#            norm_alpha_read_covers_snps_count_exact  \
# SRR2240322                                     0.0
# SRR2240323                                     0.0
# SRR2240324                                     NaN
# SRR2240325                                     0.0
# SRR2240326                                     0.0
#
#            norm_alpha_dup_read_covers_snps_count_exact  \
# SRR2240322                                         0.0
# SRR2240323                                         0.0
# SRR2240324                                         NaN
# SRR2240325                                         0.0
# SRR2240326                                         0.0
#
#            norm_beta_read_covers_snps_count_exact
# SRR2240322                                    0.0
# SRR2240323                                    0.0
# SRR2240324                                    NaN
# SRR2240325                                    0.0
# SRR2240326                                    0.0
#
# [5 rows x 61 columns]
