# %%
import glob
import csv

# %%
files = glob.glob('../../results/aml_results/*.depth.txt')

# %%
master_list = []


for file in files[1:2]:
    
    name = str(file)
    
    with open(file, 'rt') as csvfile:
    
        spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in spamreader:
            
            record_list = []
# Out:
# ['Alpha_GEX_64k_HEX', '1', '0']
# ['Alpha_GEX_64k_HEX', '2', '0']
# ['Alpha_GEX_64k_HEX', '3', '0']
# ['Alpha_GEX_64k_HEX', '4', '0']
# ['Alpha_GEX_64k_HEX', '5', '0']
# ['Alpha_GEX_64k_HEX', '6', '0']
# ['Alpha_GEX_64k_HEX', '7', '0']
# ['Alpha_GEX_64k_HEX', '8', '0']
# ['Alpha_GEX_64k_HEX', '9', '0']
# ['Alpha_GEX_64k_HEX', '10', '0']
# ['Alpha_GEX_64k_HEX', '11', '0']
# ['Alpha_GEX_64k_HEX', '12', '0']
# ['Alpha_GEX_64k_HEX', '13', '0']
# ['Alpha_GEX_64k_HEX', '14', '0']
# ['Alpha_GEX_64k_HEX', '15', '0']
# ['Alpha_GEX_64k_HEX', '16', '0']
# ['Alpha_GEX_64k_HEX', '17', '0']
# ['Alpha_GEX_64k_HEX', '18', '0']
# ['Alpha_GEX_64k_HEX', '19', '0']
# ['Alpha_GEX_64k_HEX', '20', '0']
# ['Alpha_GEX_64k_HEX', '21', '0']
# ['Alpha_GEX_64k_HEX', '22', '0']
# ['Alpha_GEX_64k_HEX', '23', '0']
# ['Alpha_GEX_64k_HEX', '24', '0']
# ['Alpha_GEX_64k_HEX', '25', '2']
# ['Alpha_GEX_64k_HEX', '26', '2']
# ['Alpha_GEX_64k_HEX', '27', '4']
# ['Alpha_GEX_64k_HEX', '28', '5']
# ...
