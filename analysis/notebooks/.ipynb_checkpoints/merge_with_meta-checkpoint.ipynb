# %%
import pandas as pd
import re

# %%
df_meta = pd.read_csv('../../accession_lists/diabetes.SraRunTable.txt', sep='\t')
df_data = pd.read_csv('../data_files/diabetes.diabetes.csv', index_col=0)
output_name = 'diabetes.meta.mbase_norm.csv'
normalise_with_mbases = True

# %%
df_data.head()
# Out:
#                                                                                  file_location  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
#
#                                               source  alignment_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  allergy              108
# aab_spliced_asthma.ERR237018.sam.sorted.bam  allergy               63
# aab_spliced_asthma.ERR237019.sam.sorted.bam  allergy               27
# aab_spliced_asthma.ERR237020.sam.sorted.bam  allergy               84
# aab_spliced_asthma.ERR237021.sam.sorted.bam  allergy               14
#
#                                              alpha_wt_count  alpha_dup_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam              35               35
# aab_spliced_asthma.ERR237018.sam.sorted.bam              20               20
# aab_spliced_asthma.ERR237019.sam.sorted.bam               8                8
# aab_spliced_asthma.ERR237020.sam.sorted.bam              26               26
# aab_spliced_asthma.ERR237021.sam.sorted.bam               4                4
#
#                                              beta_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam          38
# aab_spliced_asthma.ERR237018.sam.sorted.bam          23
# aab_spliced_asthma.ERR237019.sam.sorted.bam          11
# aab_spliced_asthma.ERR237020.sam.sorted.bam          32
# aab_spliced_asthma.ERR237021.sam.sorted.bam           6
#
#                                              alpha_wt_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                        33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                        17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                         8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                        25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                         4
#
#                                              alpha_dup_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                         33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                         17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                          8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                         25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                          4
#
#                                              beta_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                    35
# aab_spliced_asthma.ERR237018.sam.sorted.bam                    19
# aab_spliced_asthma.ERR237019.sam.sorted.bam                     7
# aab_spliced_asthma.ERR237020.sam.sorted.bam                    30
# aab_spliced_asthma.ERR237021.sam.sorted.bam                     6
#
#                                              alpha_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                             0
#
#                                              alpha_dup_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                 0
#
#                                              beta_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                            0
#
#                                              alpha_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                   0
#
#                                              alpha_dup_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                       0
#
#                                              beta_read_covers_snps_count_exact
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                  0

# %%
def get_srr_accession(df):
    
    pattern = re.compile(r"[DSE]RR[0-9]+")
    
    file = df['file_location']
    
    return re.search(pattern, file).group(0)

# %%
df_data['srr_acc'] = df_data.apply(get_srr_accession, axis=1)

# %%
df_data.set_index('srr_acc',inplace=True)

# %%
df_data.head()
# Out:
#                                                file_location   source  \
# srr_acc
# ERR237015  ../results/asthma_results/aab_spliced_asthma.E...  allergy
# ERR237018  ../results/asthma_results/aab_spliced_asthma.E...  allergy
# ERR237019  ../results/asthma_results/aab_spliced_asthma.E...  allergy
# ERR237020  ../results/asthma_results/aab_spliced_asthma.E...  allergy
# ERR237021  ../results/asthma_results/aab_spliced_asthma.E...  allergy
#
#            alignment_count  alpha_wt_count  alpha_dup_count  beta_count  \
# srr_acc
# ERR237015              108              35               35          38
# ERR237018               63              20               20          23
# ERR237019               27               8                8          11
# ERR237020               84              26               26          32
# ERR237021               14               4                4           6
#
#            alpha_wt_zero_edit_count  alpha_dup_zero_edit_count  \
# srr_acc
# ERR237015                        33                         33
# ERR237018                        17                         17
# ERR237019                         8                          8
# ERR237020                        25                         25
# ERR237021                         4                          4
#
#            beta_zero_edit_count  alpha_read_covers_snps_count  \
# srr_acc
# ERR237015                    35                             0
# ERR237018                    19                             0
# ERR237019                     7                             0
# ERR237020                    30                             0
# ERR237021                     6                             0
#
#            alpha_dup_read_covers_snps_count  beta_read_covers_snps_count  \
# srr_acc
# ERR237015                                 0                            0
# ERR237018                                 0                            0
# ERR237019                                 0                            0
# ERR237020                                 0                            0
# ERR237021                                 0                            0
#
#            alpha_read_covers_snps_count_exact  \
# srr_acc
# ERR237015                                   0
# ERR237018                                   0
# ERR237019                                   0
# ERR237020                                   0
# ERR237021                                   0
#
#            alpha_dup_read_covers_snps_count_exact  \
# srr_acc
# ERR237015                                       0
# ERR237018                                       0
# ERR237019                                       0
# ERR237020                                       0
# ERR237021                                       0
#
#            beta_read_covers_snps_count_exact
# srr_acc
# ERR237015                                  0
# ERR237018                                  0
# ERR237019                                  0
# ERR237020                                  0
# ERR237021                                  0

# %%
df_meta.set_index('Run', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Run'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-77b950463d64> in <module>()
# ----> 1 df_meta.set_index('Run', inplace=True)
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3144                 names.append(None)
#    3145             else:
# -> 3146                 level = frame[col]._values
#    3147                 names.append(col)
#    3148                 if drop:
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Run'

# %%
df_meta.head()

# %%
del df_meta.index.name
del df_data.index.name

# %%
df_meta.head()

# %%
master_df = df_meta.join(df_data)

# %%
master_df.columns

# %%
if normalise_with_mbases == True:


    master_df['norm_alignment_count'] = master_df['alignment_count'] / (master_df['MBases'])
    master_df['norm_alpha_wt_count'] = master_df['alpha_wt_count'] / (master_df['MBases'])
    master_df['norm_alpha_dup_count'] = master_df['alpha_dup_count'] / (master_df['MBases'])
    master_df['norm_beta_count'] = master_df['beta_count'] / (master_df['MBases'])
    master_df['norm_alpha_read_covers_snps_count_exact'] = master_df['alpha_read_covers_snps_count_exact'] / (master_df['MBases'])
    master_df['norm_alpha_dup_read_covers_snps_count_exact'] = master_df['alpha_dup_read_covers_snps_count_exact'] / (master_df['MBases'])
    master_df['norm_beta_read_covers_snps_count_exact'] = master_df['beta_read_covers_snps_count_exact'] / (master_df['MBases'])

# %%
master_df.head()

# %%
master_df.to_csv(output_name)

# %%
master_df.head()
