# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
aml_df = pd.read_csv('../data_files/aml.normal.meta.filtered.csv', index_col=0)
#allergy_df = pd.read_csv('../data_files/allergy.allergy.normal.csv', index_col=0)
#diabetes_df = pd.read_csv('../data_files/diabetes.diabetes.normal.csv', index_col=0)
#diabetes_control_df = pd.read_csv('../data_files/diabetes_control.diabetes_control.normal.csv', index_col=0)
control_df = pd.read_csv('../data_files/geuvadis.normal.meta.filtered.csv', index_col=0)

# %%
master_df = aml_df.append([control_df])

# %%
master_df.shape
# Out:
# (1841, 51)

# %%
master_df.columns
# Out:
# Index(['Assay_Type', 'AssemblyName', 'AvgSpotLen', 'BioProject', 'BioSample',
#        'Center_Name', 'Consent', 'DATASTORE_filetype', 'DATASTORE_provider',
#        'ENA_FIRST_PUBLIC', 'ENA_LAST_UPDATE', 'Experiment', 'InsertSize',
#        'Instrument', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
#        'Library_Name', 'LoadDate', 'MBases', 'MBytes', 'Organism', 'Platform',
#        'ReleaseDate', 'SRA_Sample', 'SRA_Study', 'Sample_Name', 'Strain',
#        'alignment_count', 'alpha_dup_count',
#        'alpha_dup_read_covers_snps_count',
#        'alpha_dup_read_covers_snps_count_exact', 'alpha_dup_zero_edit_count',
#        'alpha_read_covers_snps_count', 'alpha_read_covers_snps_count_exact',
#        'alpha_wt_count', 'alpha_wt_zero_edit_count', 'beta_count',
#        'beta_read_covers_snps_count', 'beta_read_covers_snps_count_exact',
#        'beta_zero_edit_count', 'cell_type', 'file_location',
#        'norm_alpha_dup_read_covers_snps_count_exact',
#        'norm_alpha_read_covers_snps_count_exact',
#        'norm_beta_read_covers_snps_count_exact', 'population', 'source',
#        'source_name', 'tissue', 'total_spots'],
#       dtype='object')

# %%
master_df.describe()
# Out:
#        AssemblyName   AvgSpotLen   InsertSize        MBases        MBytes  \
# count           0.0  1841.000000  1841.000000   1841.000000   1841.000000
# mean            NaN   182.043455   101.140684   5599.058664   3220.103205
# std             NaN    23.889198   134.535442   3150.217681   1500.760968
# min             NaN   150.000000     0.000000   1005.000000    627.000000
# 25%             NaN   150.000000     0.000000   3015.000000   2049.000000
# 50%             NaN   200.000000     0.000000   4546.000000   3089.000000
# 75%             NaN   200.000000   280.000000   8573.000000   4278.000000
# max             NaN   200.000000   280.000000  33842.000000  23763.000000
#
#        alignment_count  alpha_dup_count  alpha_dup_read_covers_snps_count  \
# count      1841.000000      1841.000000                       1841.000000
# mean       2364.135796       895.657795                         26.757740
# std        8197.883344      3968.338575                        190.714808
# min           0.000000         0.000000                          0.000000
# 25%           7.000000         2.000000                          0.000000
# 50%         157.000000        20.000000                          0.000000
# 75%        1690.000000       373.000000                          0.000000
# max      128617.000000     66448.000000                       3108.000000
#
#        alpha_dup_read_covers_snps_count_exact  alpha_dup_zero_edit_count  \
# count                             1841.000000                1841.000000
# mean                                21.942966                 680.699620
# std                                159.727858                3408.379995
# min                                  0.000000                   0.000000
# 25%                                  0.000000                   2.000000
# 50%                                  0.000000                  11.000000
# 75%                                  0.000000                 174.000000
# max                               2727.000000               59756.000000
#
#            ...       alpha_wt_count  alpha_wt_zero_edit_count    beta_count  \
# count      ...          1841.000000               1841.000000   1841.000000
# mean       ...           906.718631                671.363389    561.759370
# std        ...          3789.703622               3220.229993   1479.951524
# min        ...             0.000000                  0.000000      0.000000
# 25%        ...             2.000000                  2.000000      2.000000
# 50%        ...            21.000000                 11.000000     36.000000
# 75%        ...           403.000000                185.000000    409.000000
# max        ...         62044.000000              55942.000000  17553.000000
#
#        beta_read_covers_snps_count  beta_read_covers_snps_count_exact  \
# count                  1841.000000                        1841.000000
# mean                     44.648017                          36.566540
# std                     130.670699                         110.003068
# min                       0.000000                           0.000000
# 25%                       0.000000                           0.000000
# 50%                       1.000000                           1.000000
# 75%                      29.000000                          23.000000
# max                    1573.000000                        1430.000000
#
#        beta_zero_edit_count  norm_alpha_dup_read_covers_snps_count_exact  \
# count           1841.000000                                  1841.000000
# mean             365.278653                                     1.011564
# std              998.178965                                     7.299550
# min                0.000000                                     0.000000
# 25%                2.000000                                     0.000000
# 50%               27.000000                                     0.000000
# 75%              267.000000                                     0.000000
# max            12437.000000                                    74.326065
#
#        norm_alpha_read_covers_snps_count_exact  \
# count                              1841.000000
# mean                                  0.550419
# std                                   2.451475
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.045372
# max                                  33.294673
#
#        norm_beta_read_covers_snps_count_exact   total_spots
# count                             1841.000000  1.841000e+03
# mean                                 1.417120  3.173521e+07
# std                                  4.201169  1.589499e+07
# min                                  0.000000  5.272381e+06
# 25%                                  0.000000  1.773076e+07
# 50%                                  0.016612  2.890669e+07
# 75%                                  0.726130  4.572494e+07
# max                                 42.564971  1.774319e+08
#
# [8 rows x 22 columns]

# %%
#How many of each type do we have?
fig, ax = plt.subplots(figsize=(8,8))
sns.countplot(x='source', data=master_df)

# %%
#What are the expression levels of each type?
fig, ax = plt.subplots(3,1,figsize=(8,8))
sns.barplot(x='source', y='norm_alpha_read_covers_snps_count_exact', data=master_df, ax=ax[0])
sns.barplot(x='source', y='norm_alpha_dup_read_covers_snps_count_exact', data=master_df, ax=ax[1])
sns.barplot(x='source', y='norm_beta_read_covers_snps_count_exact', data=master_df, ax=ax[2])

ax[0].set_ylabel('Alpha WT (RPM)')
ax[1].set_ylabel('Alpha DUP (RPM)')
ax[2].set_ylabel('Beta (RPM)')
plt.tight_layout()

# %%
plot = sns.pairplot(x_vars=["norm_alpha_read_covers_snps_count_exact"], y_vars=["norm_alpha_dup_read_covers_snps_count_exact"], data=master_df, hue="source", size=10)

axes = plot.axes

#axes[0,0].set_ylim(-2,80)
#axes[0,0].set_xlim(-2,40)

# %%
#Ones with highest alpha dup expression

#master_df[master_df['norm_alpha_dup_read_covers_snps_count_exact'] > 40].sort_values('norm_alpha_dup_read_covers_snps_count_exact', ascending=False)

# %%
sns.barplot(x='source', y='alpha_wt_count', data=master_df)

# %%
control_df.describe()
# Out:
#        AvgSpotLen  InsertSize        MBases       MBytes  alignment_count  \
# count  665.000000       665.0    665.000000   665.000000       665.000000
# mean   150.288722       280.0   3802.410526  2647.765414         5.885714
# std      0.703440         0.0   1396.586683   983.063784         6.325188
# min    150.000000       280.0   1235.000000   867.000000         0.000000
# 25%    150.000000       280.0   2709.000000  1862.000000         2.000000
# 50%    150.000000       280.0   3779.000000  2660.000000         4.000000
# 75%    150.000000       280.0   4565.000000  3209.000000         8.000000
# max    152.000000       280.0  11919.000000  7977.000000        59.000000
#
#        alpha_wt_count  alpha_dup_count  beta_count  alpha_wt_zero_edit_count  \
# count      665.000000       665.000000  665.000000                665.000000
# mean         1.926316         1.905263    2.054135                  1.753383
# std          2.413376         2.395098    2.127010                  2.173760
# min          0.000000         0.000000    0.000000                  0.000000
# 25%          0.000000         0.000000    1.000000                  0.000000
# 50%          1.000000         1.000000    2.000000                  1.000000
# 75%          3.000000         3.000000    3.000000                  2.000000
# max         23.000000        23.000000   24.000000                 21.000000
#
#        alpha_dup_zero_edit_count                   ...                    \
# count                 665.000000                   ...
# mean                    1.732331                   ...
# std                     2.155951                   ...
# min                     0.000000                   ...
# 25%                     0.000000                   ...
# 50%                     1.000000                   ...
# 75%                     2.000000                   ...
# max                    21.000000                   ...
#
#        alpha_read_covers_snps_count  alpha_dup_read_covers_snps_count  \
# count                    665.000000                             665.0
# mean                       0.004511                               0.0
# std                        0.067065                               0.0
# min                        0.000000                               0.0
# 25%                        0.000000                               0.0
# 50%                        0.000000                               0.0
# 75%                        0.000000                               0.0
# max                        1.000000                               0.0
#
#        beta_read_covers_snps_count  alpha_read_covers_snps_count_exact  \
# count                   665.000000                          665.000000
# mean                      0.003008                            0.004511
# std                       0.054800                            0.067065
# min                       0.000000                            0.000000
# 25%                       0.000000                            0.000000
# 50%                       0.000000                            0.000000
# 75%                       0.000000                            0.000000
# max                       1.000000                            1.000000
#
#        alpha_dup_read_covers_snps_count_exact  \
# count                                   665.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        beta_read_covers_snps_count_exact   total_spots  \
# count                         665.000000  6.650000e+02
# mean                            0.003008  2.651988e+07
# std                             0.054800  9.710164e+06
# min                             0.000000  8.639677e+06
# 25%                             0.000000  1.893928e+07
# 50%                             0.000000  2.630470e+07
# 75%                             0.000000  3.185266e+07
# max                             1.000000  8.332160e+07
#
#        norm_alpha_read_covers_snps_count_exact  \
# count                               665.000000
# mean                                  0.000097
# std                                   0.001540
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   0.032553
#
#        norm_alpha_dup_read_covers_snps_count_exact  \
# count                                        665.0
# mean                                           0.0
# std                                            0.0
# min                                            0.0
# 25%                                            0.0
# 50%                                            0.0
# 75%                                            0.0
# max                                            0.0
#
#        norm_beta_read_covers_snps_count_exact
# count                              665.000000
# mean                                 0.000134
# std                                  0.002731
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  0.066677
#
# [8 rows x 21 columns]

# %%
master_df['source'].value_counts()
# Out:
# AML         1176
# geuvadis     665
# Name: source, dtype: int64

# %%
sns.barplot(x='source', y='alignment_count', data=master_df)

# %%
control_df[['alignment_count']].sort_values('alignment_count', ascending=False).head(50)
# Out:
#            alignment_count
# ERR204940               59
# ERR188469               47
# ERR188275               46
# ERR188296               34
# ERR188150               34
# ERR188455               32
# ERR188437               31
# ERR188223               31
# ERR188084               30
# ERR188259               29
# ERR188418               28
# ERR188427               25
# ERR188294               24
# ERR188195               23
# ERR188393               23
# ERR188281               22
# ERR188231               22
# ERR188454               22
# ERR188153               21
# ERR188395               21
# ERR188271               21
# ERR188224               20
# ERR188257               20
# ERR188161               20
# ERR188159               19
# ERR188363               19
# ERR204897               19
# ERR188291               18
# ERR188112               18
# ERR204861               18
# ERR188168               18
# ERR188240               18
# ERR188219               18
# ERR188339               17
# ERR204950               17
# ERR188243               17
# ERR204954               17
# ERR188350               16
# ERR188023               16
# ERR188237               16
# ERR188269               16
# ERR188035               16
# ERR188247               16
# ERR204947               15
# ERR204993               15
# ERR188070               15
# ERR188027               15
# ERR188478               15
# ERR205021               15
# ERR188338               15

# %%
grouped = master_df.groupby('source')

# %%
grouped.max()
# Out:
#          Assay_Type  AssemblyName  AvgSpotLen   BioProject     BioSample  \
# source
# AML         RNA-Seq           NaN         200  PRJNA278767  SAMN03431267
# geuvadis    RNA-Seq           NaN         152    PRJEB3366  SAMEA1573546
#
#                  Center_Name Consent DATASTORE_filetype DATASTORE_provider  \
# source
# AML                      GEO  public                sra               ncbi
# geuvadis  Uppsala University  public                sra               ncbi
#
#          ENA_FIRST_PUBLIC     ...      beta_zero_edit_count  \
# source                        ...
# AML                   NaN     ...                     12437
# geuvadis       2012-11-06     ...                        19
#
#                                    cell_type  \
# source
# AML       acute myeloid leukemia (AML) cells
# geuvadis                                 NaN
#
#                                               file_location  \
# source
# AML       ../aml_results/aml_aabspliced_SRR1918759.sam.s...
# geuvadis  ../geuvadis_results/geuvadis.ERR205023.sam.sor...
#
#          norm_alpha_dup_read_covers_snps_count_exact  \
# source
# AML                                        74.326065
# geuvadis                                    0.000000
#
#          norm_alpha_read_covers_snps_count_exact  \
# source
# AML                                    33.294673
# geuvadis                                0.032553
#
#          norm_beta_read_covers_snps_count_exact population  \
# source
# AML                                   42.564971        NaN
# geuvadis                               0.066677        YRI
#
#                      source_name         tissue  total_spots
# source
# AML       acute myeloid leukemia  Leukapheresis    177431890
# geuvadis                     NaN            NaN     83321601
#
# [2 rows x 50 columns]

# %%
master_df[master_df['source'] == 'geuvadis'][['alpha_dup_read_covers_snps_count']].sort_values('alpha_dup_read_covers_snps_count', ascending=False).head()
# Out:
#            alpha_dup_read_covers_snps_count
# ERR188077                                 0
# ERR188454                                 0
# ERR188452                                 0
# ERR188445                                 0
# ERR188441                                 0

# %%
master_df['beta_count'].sum()
# Out:
# 1034199
