# %%
import pandas as pd
import re
from Bio import Entrez
import xml.etree.ElementTree as ET
import time

# %%
df = pd.read_csv('../test.csv', index_col=0)

# %%
df.head()
# Out:
#                                                                                  file_location  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
#
#                                              source  alignment_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  asthma              108
# aab_spliced_asthma.ERR237018.sam.sorted.bam  asthma               63
# aab_spliced_asthma.ERR237019.sam.sorted.bam  asthma               27
# aab_spliced_asthma.ERR237020.sam.sorted.bam  asthma               84
# aab_spliced_asthma.ERR237021.sam.sorted.bam  asthma               14
#
#                                              alpha_wt_count  alpha_dup_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam              35               35
# aab_spliced_asthma.ERR237018.sam.sorted.bam              20               20
# aab_spliced_asthma.ERR237019.sam.sorted.bam               8                8
# aab_spliced_asthma.ERR237020.sam.sorted.bam              26               26
# aab_spliced_asthma.ERR237021.sam.sorted.bam               4                4
#
#                                              beta_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam          38
# aab_spliced_asthma.ERR237018.sam.sorted.bam          23
# aab_spliced_asthma.ERR237019.sam.sorted.bam          11
# aab_spliced_asthma.ERR237020.sam.sorted.bam          32
# aab_spliced_asthma.ERR237021.sam.sorted.bam           6
#
#                                              alpha_wt_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                        33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                        17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                         8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                        25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                         4
#
#                                              alpha_dup_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                         33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                         17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                          8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                         25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                          4
#
#                                              beta_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                    35
# aab_spliced_asthma.ERR237018.sam.sorted.bam                    19
# aab_spliced_asthma.ERR237019.sam.sorted.bam                     7
# aab_spliced_asthma.ERR237020.sam.sorted.bam                    30
# aab_spliced_asthma.ERR237021.sam.sorted.bam                     6
#
#                                              alpha_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                             0
#
#                                              alpha_dup_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                 0
#
#                                              beta_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                            0
#
#                                              alpha_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                   0
#
#                                              alpha_dup_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                       0
#
#                                              beta_read_covers_snps_count_exact
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                  0

# %%
df.columns
# Out:
# Index(['file_location', 'source', 'alignment_count', 'alpha_wt_count',
#        'alpha_dup_count', 'beta_count', 'alpha_wt_zero_edit_count',
#        'alpha_dup_zero_edit_count', 'beta_zero_edit_count',
#        'alpha_read_covers_snps_count', 'alpha_dup_read_covers_snps_count',
#        'beta_read_covers_snps_count', 'alpha_read_covers_snps_count_exact',
#        'alpha_dup_read_covers_snps_count_exact',
#        'beta_read_covers_snps_count_exact'],
#       dtype='object')

# %%
df = df[['file_location', 'source', 'alignment_count', 'alpha_wt_count',
       'alpha_dup_count', 'beta_count', 'alpha_wt_zero_edit_count',
       'alpha_dup_zero_edit_count', 'beta_zero_edit_count',
       'alpha_read_covers_snps_count', 'alpha_dup_read_covers_snps_count',
       'beta_read_covers_snps_count', 'alpha_read_covers_snps_count_exact',
       'alpha_dup_read_covers_snps_count_exact',
       'beta_read_covers_snps_count_exact']]

# %%
df.head()
# Out:
#                                                                               file_location  \
# aml_aabspliced_SRR948685.sam.sorted.bam   ../aml_results/aml_aabspliced_SRR948685.sam.so...
# aml_aabspliced_SRR948686.sam.sorted.bam   ../aml_results/aml_aabspliced_SRR948686.sam.so...
# aml_aabspliced_SRR1918637.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918637.sam.s...
# aml_aabspliced_SRR1918638.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918638.sam.s...
# aml_aabspliced_SRR1918639.sam.sorted.bam  ../aml_results/aml_aabspliced_SRR1918639.sam.s...
#
#                                          source  alignment_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam     AML              197
# aml_aabspliced_SRR948686.sam.sorted.bam     AML              161
# aml_aabspliced_SRR1918637.sam.sorted.bam    AML             3736
# aml_aabspliced_SRR1918638.sam.sorted.bam    AML             3550
# aml_aabspliced_SRR1918639.sam.sorted.bam    AML              182
#
#                                           alpha_wt_count  alpha_dup_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                8                9
# aml_aabspliced_SRR948686.sam.sorted.bam                4                4
# aml_aabspliced_SRR1918637.sam.sorted.bam            1776             1581
# aml_aabspliced_SRR1918638.sam.sorted.bam            1669             1482
# aml_aabspliced_SRR1918639.sam.sorted.bam              78               70
#
#                                           beta_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam          180
# aml_aabspliced_SRR948686.sam.sorted.bam          153
# aml_aabspliced_SRR1918637.sam.sorted.bam         379
# aml_aabspliced_SRR1918638.sam.sorted.bam         399
# aml_aabspliced_SRR1918639.sam.sorted.bam          34
#
#                                           alpha_wt_zero_edit_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                          5
# aml_aabspliced_SRR948686.sam.sorted.bam                          3
# aml_aabspliced_SRR1918637.sam.sorted.bam                       677
# aml_aabspliced_SRR1918638.sam.sorted.bam                       582
# aml_aabspliced_SRR1918639.sam.sorted.bam                        39
#
#                                           alpha_dup_zero_edit_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                           6
# aml_aabspliced_SRR948686.sam.sorted.bam                           3
# aml_aabspliced_SRR1918637.sam.sorted.bam                        631
# aml_aabspliced_SRR1918638.sam.sorted.bam                        546
# aml_aabspliced_SRR1918639.sam.sorted.bam                         37
#
#                                           beta_zero_edit_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                    108
# aml_aabspliced_SRR948686.sam.sorted.bam                     85
# aml_aabspliced_SRR1918637.sam.sorted.bam                   340
# aml_aabspliced_SRR1918638.sam.sorted.bam                   350
# aml_aabspliced_SRR1918639.sam.sorted.bam                    26
#
#                                           alpha_read_covers_snps_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                              0
# aml_aabspliced_SRR948686.sam.sorted.bam                              0
# aml_aabspliced_SRR1918637.sam.sorted.bam                           106
# aml_aabspliced_SRR1918638.sam.sorted.bam                           105
# aml_aabspliced_SRR1918639.sam.sorted.bam                             4
#
#                                           alpha_dup_read_covers_snps_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                                  0
# aml_aabspliced_SRR948686.sam.sorted.bam                                  0
# aml_aabspliced_SRR1918637.sam.sorted.bam                                 0
# aml_aabspliced_SRR1918638.sam.sorted.bam                                 0
# aml_aabspliced_SRR1918639.sam.sorted.bam                                 0
#
#                                           beta_read_covers_snps_count  \
# aml_aabspliced_SRR948685.sam.sorted.bam                             4
# aml_aabspliced_SRR948686.sam.sorted.bam                             6
# aml_aabspliced_SRR1918637.sam.sorted.bam                           21
# aml_aabspliced_SRR1918638.sam.sorted.bam                           28
# aml_aabspliced_SRR1918639.sam.sorted.bam                            0
#
#                                           alpha_read_covers_snps_count_exact  \
# aml_aabspliced_SRR948685.sam.sorted.bam                                    0
# aml_aabspliced_SRR948686.sam.sorted.bam                                    0
# aml_aabspliced_SRR1918637.sam.sorted.bam                                   0
# aml_aabspliced_SRR1918638.sam.sorted.bam                                   1
# aml_aabspliced_SRR1918639.sam.sorted.bam                                   0
#
#                                           alpha_dup_read_covers_snps_count_exact  \
# aml_aabspliced_SRR948685.sam.sorted.bam                                        0
# aml_aabspliced_SRR948686.sam.sorted.bam                                        0
# aml_aabspliced_SRR1918637.sam.sorted.bam                                       0
# aml_aabspliced_SRR1918638.sam.sorted.bam                                       0
# aml_aabspliced_SRR1918639.sam.sorted.bam                                       0
#
#                                           beta_read_covers_snps_count_exact
# aml_aabspliced_SRR948685.sam.sorted.bam                                   2
# aml_aabspliced_SRR948686.sam.sorted.bam                                   3
# aml_aabspliced_SRR1918637.sam.sorted.bam                                 16
# aml_aabspliced_SRR1918638.sam.sorted.bam                                 21
# aml_aabspliced_SRR1918639.sam.sorted.bam                                  0

# %%
def get_srr_accession(df):
    
    pattern = re.compile(r"[SE]RR[0-9]+")
    
    file = df['file_location']
    
    return re.search(pattern, file).group(0)

# %%
df['srr_acc'] = df.apply(get_srr_accession, axis=1)

# %%
df.head()
# Out:
#                                                                                  file_location  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
#
#                                              source  alignment_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  asthma              108
# aab_spliced_asthma.ERR237018.sam.sorted.bam  asthma               63
# aab_spliced_asthma.ERR237019.sam.sorted.bam  asthma               27
# aab_spliced_asthma.ERR237020.sam.sorted.bam  asthma               84
# aab_spliced_asthma.ERR237021.sam.sorted.bam  asthma               14
#
#                                              alpha_wt_count  alpha_dup_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam              35               35
# aab_spliced_asthma.ERR237018.sam.sorted.bam              20               20
# aab_spliced_asthma.ERR237019.sam.sorted.bam               8                8
# aab_spliced_asthma.ERR237020.sam.sorted.bam              26               26
# aab_spliced_asthma.ERR237021.sam.sorted.bam               4                4
#
#                                              beta_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam          38
# aab_spliced_asthma.ERR237018.sam.sorted.bam          23
# aab_spliced_asthma.ERR237019.sam.sorted.bam          11
# aab_spliced_asthma.ERR237020.sam.sorted.bam          32
# aab_spliced_asthma.ERR237021.sam.sorted.bam           6
#
#                                              alpha_wt_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                        33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                        17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                         8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                        25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                         4
#
#                                              alpha_dup_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                         33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                         17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                          8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                         25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                          4
#
#                                              beta_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                    35
# aab_spliced_asthma.ERR237018.sam.sorted.bam                    19
# aab_spliced_asthma.ERR237019.sam.sorted.bam                     7
# aab_spliced_asthma.ERR237020.sam.sorted.bam                    30
# aab_spliced_asthma.ERR237021.sam.sorted.bam                     6
#
#                                              alpha_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                             0
#
#                                              alpha_dup_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                 0
#
#                                              beta_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                            0
#
#                                              alpha_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                   0
#
#                                              alpha_dup_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                       0
#
#                                              beta_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                  0
#
#                                                srr_acc
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ERR237015
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ERR237018
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ERR237019
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ERR237020
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ERR237021

# %%
def get_spot_count(df, email):
    
    srr_acc = df['srr_acc']
    
    print (srr_acc)
    
    # get SRR id
    Entrez.email = email
    
    error_count =0
    
    while error_count < 3:
        
        try:
    
            handle = Entrez.esearch(db="sra",term=srr_acc)
    
            record = Entrez.read(handle)
        
            handle.close()
    
            srr_id = record["IdList"][0]
        
            break
            
        except:
            
            print ('id', srr_acc, error_count)
            
            time.sleep(10)
            
            error_count = error_count +1
            
            
    # get SRR summary
    
    error_count =0
    
    while error_count < 3:
        
        try:  
    
            handle = Entrez.esummary(db='sra', id=srr_id)
    
            record = Entrez.read(handle)
    
            handle.close()
    
            my_xml = record[0]['Runs']
    
            # Parse XML
            xml_object = ET.fromstringlist(["<root>", my_xml, "</root>"])
    
            # Get total_spots (reads)
            for child in xml_object:
        
                if child.attrib['acc'] == srr_acc:
                
                    print (srr_acc, child.attrib['total_spots'])
            
                    return child.attrib['total_spots']
            
            
            
            
        except:
            
            print ('summary', srr_acc, error_count)
            
            time.sleep(10)
            
            error_count = error_count +1

# %%
df['total_spots'] = df.apply(get_spot_count, axis=1, args=['halsteadjs@nih.gov'])
# Out:
# ERR237015
# ERR237015 58775477
# ERR237018
# ERR237018 69614876
# ERR237019
# ERR237019 54680365
# ERR237020
# ERR237020 87519326
# ERR237021
# ERR237021 53843103
# ERR237022
# ERR237022 67944405
# ERR237025
# ERR237025 74969417
# ERR237026
# ERR237026 62195168
# ERR237028
# ERR237028 79310739

# %%
#df.to_csv('aml_acc_spot.csv')

# %%
df['norm_alpha_read_covers_snps_count_exact'] = int(df['alpha_read_covers_snps_count_exact']) / int((df['total_spots']/ 1000000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-24d48d083c9d> in <module>()
# ----> 1 df['norm_alpha_read_covers_snps_count_exact'] = int(df['alpha_read_covers_snps_count_exact']) / int((df['total_spots']/ 1000000))
#
# /panfs/pan1.be-md.ncbi.nlm.nih.gov/product_manager_research_projects/joseph/tryptase/tryptase_project/myvenv/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     110             return converter(self.iloc[0])
#     111         raise TypeError("cannot convert the series to "
# --> 112                         "{0}".format(str(converter)))
#     113
#     114     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df
# Out:
#                                                                                  file_location  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237022.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237025.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237026.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
# aab_spliced_asthma.ERR237028.sam.sorted.bam  ../results/asthma_results/aab_spliced_asthma.E...
#
#                                              source  alignment_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam  asthma              108
# aab_spliced_asthma.ERR237018.sam.sorted.bam  asthma               63
# aab_spliced_asthma.ERR237019.sam.sorted.bam  asthma               27
# aab_spliced_asthma.ERR237020.sam.sorted.bam  asthma               84
# aab_spliced_asthma.ERR237021.sam.sorted.bam  asthma               14
# aab_spliced_asthma.ERR237022.sam.sorted.bam  asthma               24
# aab_spliced_asthma.ERR237025.sam.sorted.bam  asthma               27
# aab_spliced_asthma.ERR237026.sam.sorted.bam  asthma               81
# aab_spliced_asthma.ERR237028.sam.sorted.bam  asthma               75
#
#                                              alpha_wt_count  alpha_dup_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam              35               35
# aab_spliced_asthma.ERR237018.sam.sorted.bam              20               20
# aab_spliced_asthma.ERR237019.sam.sorted.bam               8                8
# aab_spliced_asthma.ERR237020.sam.sorted.bam              26               26
# aab_spliced_asthma.ERR237021.sam.sorted.bam               4                4
# aab_spliced_asthma.ERR237022.sam.sorted.bam               6                6
# aab_spliced_asthma.ERR237025.sam.sorted.bam               8                8
# aab_spliced_asthma.ERR237026.sam.sorted.bam              24               24
# aab_spliced_asthma.ERR237028.sam.sorted.bam              24               23
#
#                                              beta_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam          38
# aab_spliced_asthma.ERR237018.sam.sorted.bam          23
# aab_spliced_asthma.ERR237019.sam.sorted.bam          11
# aab_spliced_asthma.ERR237020.sam.sorted.bam          32
# aab_spliced_asthma.ERR237021.sam.sorted.bam           6
# aab_spliced_asthma.ERR237022.sam.sorted.bam          12
# aab_spliced_asthma.ERR237025.sam.sorted.bam          11
# aab_spliced_asthma.ERR237026.sam.sorted.bam          33
# aab_spliced_asthma.ERR237028.sam.sorted.bam          28
#
#                                              alpha_wt_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                        33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                        17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                         8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                        25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                         4
# aab_spliced_asthma.ERR237022.sam.sorted.bam                         6
# aab_spliced_asthma.ERR237025.sam.sorted.bam                         8
# aab_spliced_asthma.ERR237026.sam.sorted.bam                        24
# aab_spliced_asthma.ERR237028.sam.sorted.bam                        23
#
#                                              alpha_dup_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                         33
# aab_spliced_asthma.ERR237018.sam.sorted.bam                         17
# aab_spliced_asthma.ERR237019.sam.sorted.bam                          8
# aab_spliced_asthma.ERR237020.sam.sorted.bam                         25
# aab_spliced_asthma.ERR237021.sam.sorted.bam                          4
# aab_spliced_asthma.ERR237022.sam.sorted.bam                          6
# aab_spliced_asthma.ERR237025.sam.sorted.bam                          8
# aab_spliced_asthma.ERR237026.sam.sorted.bam                         24
# aab_spliced_asthma.ERR237028.sam.sorted.bam                         22
#
#                                              beta_zero_edit_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                    35
# aab_spliced_asthma.ERR237018.sam.sorted.bam                    19
# aab_spliced_asthma.ERR237019.sam.sorted.bam                     7
# aab_spliced_asthma.ERR237020.sam.sorted.bam                    30
# aab_spliced_asthma.ERR237021.sam.sorted.bam                     6
# aab_spliced_asthma.ERR237022.sam.sorted.bam                    10
# aab_spliced_asthma.ERR237025.sam.sorted.bam                    11
# aab_spliced_asthma.ERR237026.sam.sorted.bam                    29
# aab_spliced_asthma.ERR237028.sam.sorted.bam                    27
#
#                                              alpha_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                             0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                             0
#
#                                              alpha_dup_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                                 0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                                 0
#
#                                              beta_read_covers_snps_count  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                            0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                            0
#
#                                              alpha_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                                   0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                                   0
#
#                                              alpha_dup_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                                       0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                                       0
#
#                                              beta_read_covers_snps_count_exact  \
# aab_spliced_asthma.ERR237015.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237018.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237019.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237020.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237021.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237022.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237025.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237026.sam.sorted.bam                                  0
# aab_spliced_asthma.ERR237028.sam.sorted.bam                                  0
#
#                                                srr_acc total_spots
# aab_spliced_asthma.ERR237015.sam.sorted.bam  ERR237015    58775477
# aab_spliced_asthma.ERR237018.sam.sorted.bam  ERR237018    69614876
# aab_spliced_asthma.ERR237019.sam.sorted.bam  ERR237019    54680365
# aab_spliced_asthma.ERR237020.sam.sorted.bam  ERR237020    87519326
# aab_spliced_asthma.ERR237021.sam.sorted.bam  ERR237021    53843103
# aab_spliced_asthma.ERR237022.sam.sorted.bam  ERR237022    67944405
# aab_spliced_asthma.ERR237025.sam.sorted.bam  ERR237025    74969417
# aab_spliced_asthma.ERR237026.sam.sorted.bam  ERR237026    62195168
# aab_spliced_asthma.ERR237028.sam.sorted.bam  ERR237028    79310739
