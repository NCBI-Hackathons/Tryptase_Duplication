# %% [markdown]
# # Compare Meta Data for Tryptase Expressing vs Non-Tryptase Expressing
#
# 1) tryptase-expressing v. non-expressing – you would likely have to set some somewhat arbitrary RPKM threshold based upon controls/confidence
#
# 2) among tryptase-positive: alphaDUP-expressing v. all alpha-expressing v. non-alpha-expressing
#
# 3) if anything comes out of 2, it might make sense to iterate this back through step 1 (comparing alphaDUP v. non-expressing for instance)

# %%
import pandas as pd

# %%
df = pd.read_csv('../data_files/mbase_normed/aml.meta.mbase_norm.csv', index_col=0)

# %%
df.head()
# Out:
#           Assay_Type AssemblyName  AvgSpotLen   BioProject     BioSample  \
# SRR330925    RNA-Seq          NaN          36  PRJNA145991  SAMN00709303
# SRR330926    RNA-Seq          NaN          36  PRJNA145991  SAMN00709304
# SRR330927    RNA-Seq          NaN          36  PRJNA145991  SAMN00709305
# SRR330928    RNA-Seq          NaN          36  PRJNA145991  SAMN00709306
# SRR330929    RNA-Seq          NaN          36  PRJNA145991  SAMN00709307
#
#           Center_Name DATASTORE_filetype Experiment  InsertSize  \
# SRR330925         GEO                sra  SRX091763           0
# SRR330926         GEO                sra  SRX091764           0
# SRR330927         GEO                sra  SRX091765           0
# SRR330928         GEO                sra  SRX091766           0
# SRR330929         GEO                sra  SRX091767           0
#
#                             Instrument                  ...                    \
# ...

# %%
def has_dup(df):
    """
    Does the sample have any reads covering the snps that characterise the dup locus?
    
    """

    if df['norm_alpha_dup_read_covers_snps_count_exact'] == 0:
        
        return False
    else:
        
        return True
    
def has_tryptase()

# %%
df['has_dup'] = df.apply(has_dup, axis=1)

# %%
df['norm_alignment_count'].value_counts()
# Out:
# 0.000000     111
# 0.003937       5
# 0.002625       5
# 0.001312       4
# 0.001351       3
# 0.009186       3
# 0.002668       2
# 0.029289       2
# 0.016216       2
# 0.024557       2
# 0.043330       2
# 0.001658       2
# 0.002561       2
# 0.136364       2
# 0.020833       2
# 0.003649       1
# 0.769476       1
# 0.024295       1
# 0.002807       1
# 0.603706       1
# 0.237988       1
# 0.268441       1
# 0.013686       1
# 0.242475       1
# 0.016262       1
# 0.034875       1
# 0.125607       1
# 0.671599       1
# 0.075885       1
# 0.003125       1
#             ...
# 0.812070       1
# 0.007208       1
# 0.003368       1
# 0.561208       1
# 0.004647       1
# 0.013189       1
# 0.015756       1
# 0.621366       1
# 0.026144       1
# 18.869549      1
# 0.062935       1
# 0.034346       1
# 2.196636       1
# 1.117069       1
# 0.018075       1
# 0.011550       1
# 1.026758       1
# 0.574143       1
# 0.739311       1
# 0.009770       1
# 1.233262       1
# ...
