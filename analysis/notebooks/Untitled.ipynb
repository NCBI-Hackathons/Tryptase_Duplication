# %%
import pandas as pd

# %%
df = pd.read_csv('../data_files/geuvadis.normal.meta.filtered.csv', index_col=0)

# %%
df[['alignment_count']].sort_values('alignment_count', ascending=False)
# Out:
#            alignment_count
# ERR204940               59
# ERR188469               47
# ERR188275               46
# ERR188296               34
# ERR188150               34
# ERR188455               32
# ERR188437               31
# ERR188223               31
# ERR188084               30
# ERR188259               29
# ERR188418               28
# ERR188427               25
# ERR188294               24
# ERR188195               23
# ERR188393               23
# ERR188281               22
# ERR188231               22
# ERR188454               22
# ERR188153               21
# ERR188395               21
# ERR188271               21
# ERR188224               20
# ERR188257               20
# ERR188161               20
# ERR188159               19
# ERR188363               19
# ERR204897               19
# ERR188291               18
# ERR188112               18
# ERR204861               18
# ...                    ...
# ERR204921                0
# ERR188463                0
# ...
